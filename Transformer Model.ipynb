# %% [markdown]
# ## Imports

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install emoji
# !pip install transformers
# !pip install tensorflow
# !pip install keras
# !pip install gpt_2_simple
# Out:
# Requirement already satisfied: emoji in c:\users\jonnah\anaconda3\lib\site-packages (2.2.0)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Error parsing requirements for tensorflow-gpu: [Errno 2] No such file or directory: 'c:\\users\\jonnah\\appdata\\roaming\\python\\python38\\site-packages\\tensorflow_gpu-2.2.0.dist-info\\METADATA'
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# Requirement already satisfied: transformers in c:\users\jonnah\anaconda3\lib\site-packages (4.24.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\jonnah\anaconda3\lib\site-packages (from transformers) (4.50.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\jonnah\anaconda3\lib\site-packages (from transformers) (0.13.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\jonnah\anaconda3\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: filelock in c:\users\jonnah\anaconda3\lib\site-packages (from transformers) (3.0.12)
# Requirement already satisfied: requests in c:\users\jonnah\anaconda3\lib\site-packages (from transformers) (2.24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\jonnah\anaconda3\lib\site-packages (from transformers) (5.3.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\jonnah\anaconda3\lib\site-packages (from transformers) (2020.10.15)
# Requirement already satisfied: numpy>=1.17 in c:\users\jonnah\anaconda3\lib\site-packages (from transformers) (1.23.5)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in c:\users\jonnah\anaconda3\lib\site-packages (from transformers) (0.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\jonnah\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\jonnah\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\jonnah\anaconda3\lib\site-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\jonnah\anaconda3\lib\site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jonnah\anaconda3\lib\site-packages (from requests->transformers) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jonnah\anaconda3\lib\site-packages (from requests->transformers) (1.25.11)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Error parsing requirements for tensorflow-gpu: [Errno 2] No such file or directory: 'c:\\users\\jonnah\\appdata\\roaming\\python\\python38\\site-packages\\tensorflow_gpu-2.2.0.dist-info\\METADATA'
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# Collecting tensorflow
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Error parsing requirements for tensorflow-gpu: [Errno 2] No such file or directory: 'c:\\users\\jonnah\\appdata\\roaming\\python\\python38\\site-packages\\tensorflow_gpu-2.2.0.dist-info\\METADATA'
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
#   Using cached tensorflow-2.11.0-cp38-cp38-win_amd64.whl (1.9 kB)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.3.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.23.5)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.1.0)
# Collecting keras<2.12,>=2.11.0
#   Using cached keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.14.0)
# Requirement already satisfied: packaging in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (21.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.3.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (14.0.6)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.12.1)
# Requirement already satisfied: setuptools in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (50.3.1.post20201107)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (22.10.26)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.10.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.34.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.15.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.27.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.7.4.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\jonnah\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.35.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.24.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.23.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\jonnah\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow) (2.4.7)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jonnah\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jonnah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\jonnah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\jonnah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jonnah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.25.11)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jonnah\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.0.1)
# Installing collected packages: keras, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: Keras 2.1.6
#     Uninstalling Keras-2.1.6:
#       Successfully uninstalled Keras-2.1.6
# Successfully installed keras-2.11.0 tensorflow-2.11.0
# Requirement already satisfied: keras in c:\users\jonnah\anaconda3\lib\site-packages (2.11.0)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Error parsing requirements for tensorflow-gpu: [Errno 2] No such file or directory: 'c:\\users\\jonnah\\appdata\\roaming\\python\\python38\\site-packages\\tensorflow_gpu-2.2.0.dist-info\\METADATA'
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# Requirement already satisfied: gpt_2_simple in c:\users\jonnah\anaconda3\lib\site-packages (0.8.1)
# Requirement already satisfied: toposort in c:\users\jonnah\anaconda3\lib\site-packages (from gpt_2_simple) (1.7)
# Requirement already satisfied: numpy in c:\users\jonnah\anaconda3\lib\site-packages (from gpt_2_simple) (1.23.5)
# Requirement already satisfied: regex in c:\users\jonnah\anaconda3\lib\site-packages (from gpt_2_simple) (2020.10.15)
# Requirement already satisfied: requests in c:\users\jonnah\anaconda3\lib\site-packages (from gpt_2_simple) (2.24.0)
# Requirement already satisfied: tensorflow>=2.5.1 in c:\users\jonnah\anaconda3\lib\site-packages (from gpt_2_simple) (2.11.0)
# Requirement already satisfied: tqdm in c:\users\jonnah\anaconda3\lib\site-packages (from gpt_2_simple) (4.50.2)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow>=2.5.1->gpt_2_simple) (2.11.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (1.34.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (14.0.6)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (1.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (3.7.4.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (1.15.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (0.3.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (1.3.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (2.11.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (2.10.0)
# Requirement already satisfied: setuptools in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (50.3.1.post20201107)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (1.6.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (3.14.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (0.27.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (1.12.1)
# Requirement already satisfied: packaging in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (21.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (3.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (22.10.26)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (2.11.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\jonnah\anaconda3\lib\site-packages (from requests->gpt_2_simple) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jonnah\anaconda3\lib\site-packages (from requests->gpt_2_simple) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\jonnah\anaconda3\lib\site-packages (from requests->gpt_2_simple) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jonnah\anaconda3\lib\site-packages (from requests->gpt_2_simple) (2020.6.20)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\jonnah\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (0.35.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (3.3.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (1.23.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\jonnah\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (1.7.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (0.4.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\jonnah\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (2.4.7)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (4.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (4.6)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jonnah\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jonnah\appdata\roaming\python\python38\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jonnah\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.5.1->gpt_2_simple) (3.0.1)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Error parsing requirements for tensorflow-gpu: [Errno 2] No such file or directory: 'c:\\users\\jonnah\\appdata\\roaming\\python\\python38\\site-packages\\tensorflow_gpu-2.2.0.dist-info\\METADATA'
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)

# %%
# !pip3 uninstall keras-nightly
# !pip3 uninstall -y tensorflow
# !pip3 install keras==2.1.6
# !pip3 install tensorflow==1.15.0
# !pip3 install h5py==2.10.0
# Out:
# Found existing installation: keras-nightly 2.5.0.dev2021032900
# Uninstalling keras-nightly-2.5.0.dev2021032900:
#   Would remove:
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\*
#     c:\users\jonnah\anaconda3\lib\site-packages\keras_nightly-2.5.0.dev2021032900.dist-info\*
#   Would not remove (might be manually added):
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v1\keras\__internal__\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v1\keras\__internal__\layers\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v1\keras\__internal__\legacy\__init__.py
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygame (c:\users\jonnah\anaconda3\lib\site-packages)
# ^C
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v1\keras\__internal__\legacy\layers\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v1\keras\__internal__\legacy\layers\experimental\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v1\keras\__internal__\legacy\rnn_cell\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v1\keras\applications\convnext\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v1\keras\applications\efficientnet_v2\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v1\keras\applications\regnet\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v1\keras\applications\resnet_rs\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v1\keras\optimizers\legacy\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v2\keras\__internal__\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v2\keras\__internal__\backend\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v2\keras\__internal__\layers\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v2\keras\__internal__\losses\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v2\keras\__internal__\models\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v2\keras\__internal__\optimizers\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v2\keras\__internal__\utils\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v2\keras\applications\convnext\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v2\keras\applications\efficientnet_v2\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v2\keras\applications\regnet\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v2\keras\applications\resnet_rs\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v2\keras\backend\experimental\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v2\keras\dtensor\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v2\keras\dtensor\experimental\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v2\keras\dtensor\experimental\optimizers\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v2\keras\models\experimental\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v2\keras\optimizers\experimental\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\_v2\keras\optimizers\legacy\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\keras\__internal__\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\keras\__internal__\layers\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\keras\__internal__\legacy\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\keras\__internal__\legacy\layers\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\keras\__internal__\legacy\layers\experimental\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\keras\__internal__\legacy\rnn_cell\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\keras\applications\convnext\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\keras\applications\efficientnet_v2\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\keras\applications\regnet\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\keras\applications\resnet_rs\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\api\keras\optimizers\legacy\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\applications\convnext.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\applications\efficientnet_v2.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\applications\regnet.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\applications\resnet_rs.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\distribute\dataset_creator_model_fit_test_base.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\distribute\distribute_coordinator_utils.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\dtensor\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\dtensor\integration_test_utils.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\dtensor\layout_map.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\dtensor\lazy_variable.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\dtensor\optimizers.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\dtensor\test_util.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\dtensor\utils.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\engine\functional_utils.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\integration_test\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\integration_test\preprocessing_test_utils.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\activation\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\activation\elu.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\activation\leaky_relu.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\activation\prelu.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\activation\relu.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\activation\softmax.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\activation\thresholded_relu.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\attention\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\attention\additive_attention.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\attention\attention.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\attention\base_dense_attention.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\attention\multi_head_attention.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\convolutional\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\convolutional\base_conv.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\convolutional\base_depthwise_conv.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\convolutional\base_separable_conv.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\convolutional\conv1d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\convolutional\conv1d_transpose.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\convolutional\conv2d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\convolutional\conv2d_transpose.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\convolutional\conv3d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\convolutional\conv3d_transpose.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\convolutional\depthwise_conv1d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\convolutional\depthwise_conv2d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\convolutional\separable_conv1d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\convolutional\separable_conv2d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\core\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\core\activation.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\core\dense.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\core\einsum_dense.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\core\embedding.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\core\lambda_layer.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\core\masking.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\core\tf_op_layer.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\locally_connected\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\locally_connected\locally_connected1d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\locally_connected\locally_connected2d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\locally_connected\locally_connected_utils.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\merging\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\merging\add.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\merging\average.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\merging\base_merge.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\merging\concatenate.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\merging\dot.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\merging\maximum.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\merging\minimum.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\merging\multiply.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\merging\subtract.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\normalization\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\normalization\batch_normalization.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\normalization\batch_normalization_v1.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\normalization\group_normalization.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\normalization\layer_normalization.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\normalization\unit_normalization.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\pooling\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\pooling\average_pooling1d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\pooling\average_pooling2d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\pooling\average_pooling3d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\pooling\base_global_pooling1d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\pooling\base_global_pooling2d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\pooling\base_global_pooling3d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\pooling\base_pooling1d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\pooling\base_pooling2d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\pooling\base_pooling3d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\pooling\global_average_pooling1d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\pooling\global_average_pooling2d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\pooling\global_average_pooling3d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\pooling\global_max_pooling1d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\pooling\global_max_pooling2d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\pooling\global_max_pooling3d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\pooling\max_pooling1d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\pooling\max_pooling2d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\pooling\max_pooling3d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\preprocessing\hashed_crossing.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\preprocessing\preprocessing_utils.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\regularization\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\regularization\activity_regularization.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\regularization\alpha_dropout.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\regularization\dropout.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\regularization\gaussian_dropout.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\regularization\gaussian_noise.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\regularization\spatial_dropout1d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\regularization\spatial_dropout2d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\regularization\spatial_dropout3d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\reshaping\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\reshaping\cropping1d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\reshaping\cropping2d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\reshaping\cropping3d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\reshaping\flatten.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\reshaping\permute.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\reshaping\repeat_vector.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\reshaping\reshape.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\reshaping\up_sampling1d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\reshaping\up_sampling2d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\reshaping\up_sampling3d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\reshaping\zero_padding1d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\reshaping\zero_padding2d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\reshaping\zero_padding3d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\abstract_rnn_cell.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\base_conv_lstm.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\base_conv_rnn.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\base_cudnn_rnn.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\base_rnn.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\base_wrapper.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\bidirectional.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\cell_wrappers.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\conv_lstm1d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\conv_lstm2d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\conv_lstm3d.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\cudnn_gru.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\cudnn_lstm.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\dropout_rnn_cell_mixin.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\gru.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\gru_lstm_utils.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\gru_v1.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\legacy_cell_wrappers.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\legacy_cells.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\lstm.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\lstm_v1.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\rnn_utils.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\simple_rnn.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\stacked_rnn_cells.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\layers\rnn\time_distributed.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\legacy_tf_layers\migration_utils.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\legacy_tf_layers\variable_scope_shim.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\metrics\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\metrics\base_metric.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\metrics\metrics.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\models\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\models\cloning.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\models\sharpness_aware_minimization.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\legacy\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\legacy\adadelta.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\legacy\adagrad.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\legacy\adam.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\legacy\adamax.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\legacy\ftrl.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\legacy\nadam.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\legacy\optimizer.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\legacy\rmsprop.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\legacy\sgd.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\legacy_learning_rate_decay.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_experimental\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_experimental\adadelta.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_experimental\adafactor.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_experimental\adagrad.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_experimental\adam.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_experimental\adamax.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_experimental\adamw.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_experimental\ftrl.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_experimental\nadam.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_experimental\rmsprop.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_experimental\sgd.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_v1.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adadelta.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adagrad.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adamax.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\ftrl.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\nadam.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\rmsprop.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\utils.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\schedules\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\optimizers\schedules\learning_rate_schedule.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\premade_models\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\premade_models\linear.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\premade_models\wide_deep.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\experimental\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\experimental\saving_lib.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\experimental\serialization_lib.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\hdf5_format.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\model_config.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\save.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\saved_model\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\saved_model\base_serialization.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\saved_model\constants.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\saved_model\json_utils.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\saved_model\layer_serialization.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\saved_model\load.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\saved_model\load_context.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\saved_model\metric_serialization.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\saved_model\model_serialization.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\saved_model\network_serialization.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\saved_model\order_preserving_set.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\saved_model\save.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\saved_model\save_impl.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\saved_model\serialized_attributes.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\saved_model\utils.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\saving_utils.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\legacy\serialization.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\object_registration.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\saving\pickle_utils.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\testing_infra\__init__.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\testing_infra\keras_doctest_lib.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\testing_infra\test_combinations.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\testing_infra\test_utils.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\utils\audio_dataset.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\utils\dataset_utils.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\utils\image_dataset.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\utils\image_utils.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\utils\keras_logging.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\utils\sidecar_evaluator.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\utils\text_dataset.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\utils\timeseries_dataset.py
#     c:\users\jonnah\anaconda3\lib\site-packages\keras\utils\traceback_utils.py
# Proceed (Y/n)?

# %%
import codecs
import collections
import emoji
import re
import gpt_2_simple as gpt2
from datetime import datetime
import transformers
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-1fbd849e6221> in <module>
#       3 import emoji
#       4 import re
# ----> 5 import gpt_2_simple as gpt2
#       6 from datetime import datetime
#       7 import transformers
#
# ~\anaconda3\lib\site-packages\gpt_2_simple\__init__.py in <module>
# ----> 1 from .gpt_2 import *
#
# ~\anaconda3\lib\site-packages\gpt_2_simple\gpt_2.py in <module>
#       9 import numpy as np
#      10 import tensorflow as tf
# ---> 11 from tensorflow.core.protobuf import rewriter_config_pb2
#      12 from tensorflow.python.client import device_lib
#      13 import time
#
# ImportError: cannot import name 'rewriter_config_pb2' from 'tensorflow.core.protobuf' (unknown location)

# %% [markdown]
# ## Getting Data

# %%
# specific format for JSON
with codecs.open('/content/drive/MyDrive/Colab Notebooks/CSCI 544: ANLP/NLP_Group_Project/GPT_3_Model/human_chat.txt', encoding='utf8') as f:
    data = f.read()
data = data.split('\n')

# %%
for row in data[:15]:
    print(row)

# %% [markdown]
# ## Pre-processing data

# %%
utterances = collections.defaultdict(list)

# replace emoji with text
for i in range(len(data)):

    sentence = data[i]
    data[i] = emoji.demojize(sentence)

    # removing redacted words
    data[i] = ' '.join(['' if word.startswith('<REDACTED') else word for word in data[i].split()])

    # removing extra whitespace
    data[i] = re.sub(' +', ' ', data[i])

    if sentence != data[i]:
      print('Original line: ', sentence)
      print('Transformed line: ', data[i])
      print()

    data[i] = '[' + data[i][:7] + ']' + data[i][8:]


data_to_write = '\n'.join(data)

outputfile = open("/content/drive/MyDrive/Colab Notebooks/CSCI 544: ANLP/NLP_Group_Project/GPT_3_Model/human_chat_new_processed_gpt2.txt", "wt", encoding='utf8')
n = outputfile.write(data_to_write)
outputfile.close()

# %%
for row in data[:15]:
  print(row)

# %% [markdown]
# ## Training the Transformer

# %%
# get the data file
file_path = "./human_chat_new_processed_gpt2.txt"

# initialize parameters for the GPT-2-simple
learning_rate= 0.0001
save_path= "./data/models_trained"
model_size= "124M"
steps= 600
restore_from= "fresh"
print_every= 1
sample_every= 300
save_every= 300

# %%
timestamp = datetime.utcnow().strftime('%Y%m%d%H%M%S')
model_dir = save_path
model_name = model_size
run_name = f"gp2simple_new_{model_size}_{timestamp}"
gpt2.download_gpt2(model_name=model_name, model_dir=model_dir)
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 94.3Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 5.81Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 489Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:10, 48.8Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 542Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 9.57Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 9.65Mit/s]

# %%
# Fine-Tuning the model

# Commenting the code for training since already fine-tuned and saved the model weights
"""
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              model_dir=model_dir,
              model_name=model_name,
              checkpoint_dir=model_dir,
              run_name=run_name,
              dataset=file_path,
              steps=steps,
              learning_rate=learning_rate,
              restore_from=restore_from,
              print_every=print_every,
              sample_every=sample_every,
              save_every=save_every)
"""
# Out:
# Loading checkpoint ./data/models_trained/124M\model.ckpt
# INFO:tensorflow:Restoring parameters from ./data/models_trained/124M\model.ckpt
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00,  5.29it/s]
# dataset has 32560 tokens
# Training...
# [1 | 46.45] loss=2.73 avg=2.73
# [2 | 84.30] loss=2.79 avg=2.76
# [3 | 122.23] loss=2.61 avg=2.71
# [4 | 158.99] loss=2.47 avg=2.65
# [5 | 198.33] loss=2.59 avg=2.64
# [6 | 237.67] loss=2.45 avg=2.60
# [7 | 273.43] loss=2.50 avg=2.59
# [8 | 309.22] loss=2.37 avg=2.56
# [9 | 345.35] loss=2.50 avg=2.55
# [10 | 382.43] loss=2.22 avg=2.52
# [11 | 417.51] loss=2.45 avg=2.51
# [12 | 453.66] loss=2.27 avg=2.49
# [13 | 487.90] loss=2.26 avg=2.47
# [14 | 521.64] loss=2.25 avg=2.45
# [15 | 559.90] loss=2.27 avg=2.44
# [16 | 599.65] loss=2.20 avg=2.42
# [17 | 640.53] loss=2.22 avg=2.41
# [18 | 678.83] loss=2.21 avg=2.40
# [19 | 722.59] loss=2.13 avg=2.38
# [20 | 762.31] loss=2.08 avg=2.37
# [21 | 801.19] loss=2.20 avg=2.36
# [22 | 840.38] loss=1.99 avg=2.34
# [23 | 876.70] loss=1.96 avg=2.32
# [24 | 911.85] loss=2.21 avg=2.32
# [25 | 946.89] loss=1.80 avg=2.29
# [26 | 990.79] loss=1.91 avg=2.28
# [27 | 1038.34] loss=1.93 avg=2.26
# [28 | 1081.87] loss=1.88 avg=2.25
# [29 | 1122.62] loss=1.80 avg=2.23
# [30 | 1161.75] loss=1.65 avg=2.21
# [31 | 1200.73] loss=1.91 avg=2.20
# [32 | 1240.44] loss=1.74 avg=2.18
# [33 | 1280.34] loss=1.54 avg=2.16
# [34 | 1324.84] loss=1.53 avg=2.13
# [35 | 1376.39] loss=1.84 avg=2.12
# [36 | 1420.55] loss=1.75 avg=2.11
# [37 | 1472.07] loss=1.69 avg=2.10
# [38 | 1517.57] loss=1.68 avg=2.09
# [39 | 1559.31] loss=1.73 avg=2.07
# [40 | 1600.88] loss=1.43 avg=2.05
# [41 | 1641.80] loss=1.59 avg=2.04
# [42 | 1680.39] loss=1.57 avg=2.03
# [43 | 1722.62] loss=1.38 avg=2.01
# [44 | 1768.14] loss=1.40 avg=1.99
# [45 | 1814.16] loss=1.18 avg=1.97
# [46 | 1858.71] loss=1.19 avg=1.95
# [47 | 1898.09] loss=1.31 avg=1.93
# [48 | 1937.43] loss=1.48 avg=1.92
# [49 | 1973.63] loss=1.28 avg=1.90
# [50 | 2009.99] loss=1.05 avg=1.88
# [51 | 2046.24] loss=1.42 avg=1.87
# [52 | 2082.75] loss=1.22 avg=1.85
# [53 | 2121.42] loss=1.03 avg=1.83
# [54 | 2169.72] loss=1.20 avg=1.82
# [55 | 2229.64] loss=1.08 avg=1.80
# [56 | 2281.46] loss=1.01 avg=1.78
# [57 | 2323.57] loss=1.01 avg=1.77
# [58 | 2370.90] loss=0.87 avg=1.75
# [59 | 2418.38] loss=0.95 avg=1.73
# [60 | 2461.79] loss=0.98 avg=1.71
# [61 | 2498.54] loss=0.75 avg=1.69
# [62 | 2537.85] loss=1.09 avg=1.68
# [63 | 2594.85] loss=1.07 avg=1.66
# [64 | 2639.22] loss=1.06 avg=1.65
# [65 | 2678.66] loss=0.82 avg=1.63
# [66 | 2713.67] loss=0.79 avg=1.62
# [67 | 2748.37] loss=0.69 avg=1.60
# [68 | 2782.42] loss=0.85 avg=1.58
# [69 | 2816.20] loss=0.64 avg=1.56
# [70 | 2850.07] loss=0.64 avg=1.55
# [71 | 2883.95] loss=0.60 avg=1.53
# [72 | 2918.23] loss=0.58 avg=1.51
# [73 | 2952.02] loss=0.57 avg=1.49
# [74 | 2987.41] loss=0.39 avg=1.47
# [75 | 3023.27] loss=0.76 avg=1.46
# [76 | 3070.63] loss=0.46 avg=1.44
# [77 | 3111.60] loss=0.56 avg=1.42
# [78 | 3147.50] loss=0.75 avg=1.41
# [79 | 3182.00] loss=0.45 avg=1.39
# [80 | 3216.40] loss=0.55 avg=1.38
# [81 | 3250.45] loss=0.38 avg=1.36
# [82 | 3284.17] loss=0.54 avg=1.34
# [83 | 3317.50] loss=0.32 avg=1.33
# [84 | 3351.02] loss=0.36 avg=1.31
# [85 | 3384.45] loss=0.32 avg=1.29
# [86 | 3418.16] loss=0.35 avg=1.28
# [87 | 3451.97] loss=0.31 avg=1.26
# [88 | 3485.41] loss=0.39 avg=1.24
# [89 | 3519.89] loss=0.26 avg=1.23
# [90 | 3554.10] loss=0.23 avg=1.21
# [91 | 3587.98] loss=0.42 avg=1.20
# [92 | 3621.86] loss=0.30 avg=1.18
# [93 | 3655.66] loss=0.21 avg=1.17
# [94 | 3689.66] loss=0.29 avg=1.15
# [95 | 3723.86] loss=0.38 avg=1.14
# [96 | 3758.02] loss=0.21 avg=1.12
# [97 | 3792.24] loss=0.56 avg=1.12
# [98 | 3827.51] loss=0.22 avg=1.10
# [99 | 3861.24] loss=0.18 avg=1.09
# [100 | 3904.63] loss=0.20 avg=1.07
# [101 | 3940.47] loss=0.18 avg=1.06
# [102 | 3975.39] loss=0.20 avg=1.05
# [103 | 4009.15] loss=0.16 avg=1.03
# [104 | 4043.02] loss=0.16 avg=1.02
# [105 | 4076.06] loss=0.19 avg=1.01
# [106 | 4109.42] loss=0.11 avg=0.99
# [107 | 4143.08] loss=0.12 avg=0.98
# [108 | 4176.49] loss=0.18 avg=0.97
# [109 | 4210.08] loss=0.19 avg=0.95
# [110 | 4243.38] loss=0.13 avg=0.94
# [111 | 4276.70] loss=0.14 avg=0.93
# [112 | 4314.97] loss=0.15 avg=0.92
# [113 | 4356.56] loss=0.12 avg=0.91
# [114 | 4398.27] loss=0.19 avg=0.90
# [115 | 4437.69] loss=0.14 avg=0.89
# [116 | 4476.90] loss=0.11 avg=0.87
# [117 | 4511.59] loss=0.16 avg=0.86
# [118 | 4546.05] loss=0.13 avg=0.85
# [119 | 4579.57] loss=0.17 avg=0.84
# [120 | 4612.92] loss=0.12 avg=0.83
# [121 | 4646.39] loss=0.08 avg=0.82
# [122 | 4680.22] loss=0.12 avg=0.81
# [123 | 4713.66] loss=0.07 avg=0.80
# [124 | 4747.22] loss=0.09 avg=0.79
# [125 | 4781.15] loss=0.09 avg=0.78
# [126 | 4814.16] loss=0.07 avg=0.77
# [127 | 4847.12] loss=0.06 avg=0.76
# [128 | 4880.19] loss=0.07 avg=0.75
# [129 | 4913.68] loss=0.11 avg=0.74
# [130 | 4947.39] loss=0.08 avg=0.74
# [131 | 4981.15] loss=0.09 avg=0.73
# [132 | 5014.30] loss=0.07 avg=0.72
# [133 | 5047.11] loss=0.06 avg=0.71
# [134 | 5079.62] loss=0.08 avg=0.70
# [135 | 5112.27] loss=0.07 avg=0.69
# [136 | 5145.20] loss=0.08 avg=0.68
# [137 | 5178.80] loss=0.06 avg=0.68
# [138 | 5212.44] loss=0.08 avg=0.67
# [139 | 5246.19] loss=0.08 avg=0.66
# [140 | 5279.62] loss=0.07 avg=0.65
# [141 | 5313.38] loss=0.06 avg=0.64
# [142 | 5347.08] loss=0.08 avg=0.64
# [143 | 5380.84] loss=0.09 avg=0.63
# [144 | 5414.18] loss=0.06 avg=0.62
# [145 | 5447.87] loss=0.07 avg=0.61
# [146 | 5481.45] loss=0.06 avg=0.61
# [147 | 5515.67] loss=0.07 avg=0.60
# [148 | 5550.46] loss=0.05 avg=0.59
# [149 | 5585.33] loss=0.07 avg=0.59
# [150 | 5620.48] loss=0.06 avg=0.58
# [151 | 5655.38] loss=0.06 avg=0.57
# [152 | 5689.54] loss=0.05 avg=0.57
# [153 | 5723.08] loss=0.09 avg=0.56
# [154 | 5756.63] loss=0.06 avg=0.55
# [155 | 5790.27] loss=0.07 avg=0.55
# [156 | 5823.80] loss=0.06 avg=0.54
# [157 | 5857.40] loss=0.06 avg=0.54
# [158 | 5890.78] loss=0.06 avg=0.53
# [159 | 5924.35] loss=0.04 avg=0.52
# [160 | 5957.71] loss=0.04 avg=0.52
# [161 | 5991.18] loss=0.22 avg=0.51
# [162 | 6024.44] loss=0.05 avg=0.51
# [163 | 6057.84] loss=0.06 avg=0.50
# [164 | 6091.43] loss=0.06 avg=0.50
# [165 | 6125.39] loss=0.06 avg=0.49
# [166 | 6159.34] loss=0.06 avg=0.49
# [167 | 6193.23] loss=0.06 avg=0.48
# [168 | 6226.93] loss=0.05 avg=0.48
# [169 | 6260.36] loss=0.05 avg=0.47
# [170 | 6293.89] loss=0.08 avg=0.47
# [171 | 6327.46] loss=0.06 avg=0.46
# [172 | 6361.12] loss=0.06 avg=0.46
# [173 | 6394.65] loss=0.06 avg=0.45
# [174 | 6428.14] loss=0.06 avg=0.45
# [175 | 6461.57] loss=0.04 avg=0.44
# [176 | 6495.15] loss=0.05 avg=0.44
# [177 | 6528.81] loss=0.06 avg=0.43
# [178 | 6562.59] loss=0.06 avg=0.43
# [179 | 6597.81] loss=0.04 avg=0.42
# [180 | 6631.28] loss=0.05 avg=0.42
# [181 | 6664.77] loss=0.06 avg=0.41
# [182 | 6698.34] loss=0.05 avg=0.41
# [183 | 6732.51] loss=0.04 avg=0.41
# [184 | 6766.18] loss=0.05 avg=0.40
# [185 | 6799.97] loss=0.05 avg=0.40
# [186 | 6833.34] loss=0.05 avg=0.39
# [187 | 6867.27] loss=0.04 avg=0.39
# [188 | 6900.76] loss=0.05 avg=0.39
# [189 | 6934.20] loss=0.11 avg=0.38
# [190 | 6967.73] loss=0.05 avg=0.38
# [191 | 7001.26] loss=0.06 avg=0.37
# [192 | 7034.91] loss=0.04 avg=0.37
# [193 | 7068.51] loss=0.05 avg=0.37
# [194 | 7102.02] loss=0.05 avg=0.36
# [195 | 7135.48] loss=0.04 avg=0.36
# [196 | 7168.98] loss=0.04 avg=0.36
# [197 | 7202.41] loss=0.05 avg=0.35
# [198 | 7236.01] loss=0.06 avg=0.35
# [199 | 7269.53] loss=0.05 avg=0.34
# [200 | 7303.30] loss=0.07 avg=0.34
# [201 | 7337.29] loss=0.05 avg=0.34
# [202 | 7371.24] loss=0.04 avg=0.33
# [203 | 7405.13] loss=0.06 avg=0.33
# [204 | 7438.60] loss=0.04 avg=0.33
# [205 | 7472.15] loss=0.04 avg=0.33
# [206 | 7505.64] loss=0.04 avg=0.32
# [207 | 7539.29] loss=0.03 avg=0.32
# [208 | 7572.93] loss=0.05 avg=0.32
# [209 | 7606.45] loss=0.04 avg=0.31
# [210 | 7640.37] loss=0.04 avg=0.31
# [211 | 7673.91] loss=0.06 avg=0.31
# [212 | 7707.46] loss=0.05 avg=0.30
# [213 | 7740.86] loss=0.04 avg=0.30
# [214 | 7774.70] loss=0.05 avg=0.30
# [215 | 7808.20] loss=0.05 avg=0.29
# [216 | 7841.78] loss=0.06 avg=0.29
# [217 | 7875.17] loss=0.04 avg=0.29
# [218 | 7910.58] loss=0.05 avg=0.29
# [219 | 7945.54] loss=0.05 avg=0.28
# [220 | 7979.66] loss=0.05 avg=0.28
# [221 | 8013.57] loss=0.05 avg=0.28
# [222 | 8047.22] loss=0.04 avg=0.28
# [223 | 8081.04] loss=0.04 avg=0.27
# [224 | 8114.67] loss=0.04 avg=0.27
# [225 | 8148.48] loss=0.04 avg=0.27
# [226 | 8182.11] loss=0.04 avg=0.27
# [227 | 8215.86] loss=0.04 avg=0.26
# [228 | 8248.36] loss=0.04 avg=0.26
# [229 | 8280.61] loss=0.05 avg=0.26
# [230 | 8312.61] loss=0.04 avg=0.26
# [231 | 8345.20] loss=0.03 avg=0.25
# [232 | 8377.52] loss=0.06 avg=0.25
# [233 | 8409.76] loss=0.05 avg=0.25
# [234 | 8442.57] loss=0.04 avg=0.25
# [235 | 8474.88] loss=0.04 avg=0.24
# [236 | 8507.39] loss=0.04 avg=0.24
# [237 | 8540.22] loss=0.03 avg=0.24
# [238 | 8572.84] loss=0.05 avg=0.24
# [239 | 8605.20] loss=0.03 avg=0.24
# [240 | 8637.27] loss=0.04 avg=0.23
# [241 | 8669.45] loss=0.05 avg=0.23
# [242 | 8702.04] loss=0.03 avg=0.23
# [243 | 8734.17] loss=0.05 avg=0.23
# [244 | 8766.17] loss=0.04 avg=0.23
# [245 | 8798.25] loss=0.04 avg=0.22
# [246 | 8830.63] loss=0.04 avg=0.22
# [247 | 8862.63] loss=0.04 avg=0.22
# [248 | 8894.72] loss=0.05 avg=0.22
# [249 | 8926.96] loss=0.03 avg=0.22
# [250 | 8959.07] loss=0.03 avg=0.21
# [251 | 8991.23] loss=0.05 avg=0.21
# [252 | 9025.29] loss=0.03 avg=0.21
# [253 | 9057.69] loss=0.04 avg=0.21
# [254 | 9090.47] loss=0.03 avg=0.21
# [255 | 9123.33] loss=0.03 avg=0.20
# [256 | 9156.49] loss=0.04 avg=0.20
# [257 | 9189.13] loss=0.04 avg=0.20
# [258 | 9221.83] loss=0.03 avg=0.20
# [259 | 9254.74] loss=0.04 avg=0.20
# [260 | 9287.45] loss=0.04 avg=0.20
# [261 | 9320.62] loss=0.04 avg=0.19
# [262 | 9354.18] loss=0.05 avg=0.19
# [263 | 9387.89] loss=0.04 avg=0.19
# [264 | 9421.13] loss=0.06 avg=0.19
# [265 | 9453.85] loss=0.03 avg=0.19
# [266 | 9485.95] loss=0.05 avg=0.19
# [267 | 9517.90] loss=0.04 avg=0.18
# [268 | 9550.35] loss=0.04 avg=0.18
# [269 | 9582.41] loss=0.03 avg=0.18
# [270 | 9614.87] loss=0.04 avg=0.18
# [271 | 9646.74] loss=0.04 avg=0.18
# [272 | 9678.74] loss=0.04 avg=0.18
# [273 | 9711.19] loss=0.03 avg=0.18
# [274 | 9743.52] loss=0.04 avg=0.17
# [275 | 9776.07] loss=0.04 avg=0.17
# [276 | 9808.32] loss=0.03 avg=0.17
# [277 | 9840.56] loss=0.03 avg=0.17
# [278 | 9872.70] loss=0.04 avg=0.17
# [279 | 9904.77] loss=0.04 avg=0.17
# [280 | 9936.84] loss=0.04 avg=0.17
# [281 | 9968.98] loss=0.03 avg=0.16
# [282 | 10001.16] loss=0.03 avg=0.16
# [283 | 10033.11] loss=0.03 avg=0.16
# [284 | 10065.21] loss=0.04 avg=0.16
# [285 | 10098.49] loss=0.04 avg=0.16
# [286 | 10136.05] loss=0.04 avg=0.16
# [287 | 10186.31] loss=0.04 avg=0.16
# [288 | 10227.57] loss=0.04 avg=0.15
# [289 | 10268.05] loss=0.04 avg=0.15
# [290 | 10307.47] loss=0.03 avg=0.15
# [291 | 10347.02] loss=0.04 avg=0.15
# [292 | 10384.56] loss=0.03 avg=0.15
# [293 | 10421.48] loss=0.04 avg=0.15
# [294 | 10464.05] loss=0.05 avg=0.15
# [295 | 10504.15] loss=0.05 avg=0.15
# [296 | 10543.55] loss=0.04 avg=0.15
# [297 | 10584.33] loss=0.04 avg=0.14
# [298 | 10623.98] loss=0.04 avg=0.14
# [299 | 10662.07] loss=0.04 avg=0.14
# [300 | 10698.58] loss=0.03 avg=0.14
# Saving ./data/models_trained/02_gp2simple_124M_20221120002951\model-300
# ======== SAMPLE 1 ========
#  I can work as a poodle
# [Human 2] That's a good way of framing it. I'm in a bit of a dilemma. Do I come up with a clever solution or do I stay home and work?
# [Human 1] I think I'm in the latter phase of puberty. I sometimes drift off during puberty, so I won't count them in your mind. I do know there's a medication available for side effects withv all of this speculation.
# [Human 2] I heard about tDCS before. It's a high-powered, high-tension, high-pulse, high-disruptive, very high-pulse kind of technology. It's not intended for everyday use, but could potentially be very useful in diagnosing health problems later on.
# [Human 1] EE I'm Peter Thiel. I'm cofounder oftoshi. I'm a board member ofventurecapital.com and member of theJobs World Just released a report today called "The 21st Century in Adtech." It's a fascinating time to be a Silicon Valley billionaire."
# [Human 2] The world is literally changing! How about you?
# [Human 1] I think I'm in the 21st century. I inventing ways to survive in the 21st, or whatever you want to call it, is simply terrible.
# [Human 2] hahahaha, that is a good place to start.
# [Human 1] The 21st is the most important milestone in human history. Today, we are at the turning point. I believe this country can and should live up to as they have done for many, many years.
# [Human 2] The past five presidents have been born during that time span. The other Republican has been a world leader.
# [Human 1] Both of us, what do you think makes this election more important to you?
# [Human 2] People are giving me these questions. Why are you doing these public records requests?
# [Human 1] Because I have the power to destroy the GOP.
# [Human 2] That's a much harder task, doesn't it?
# [Human 1] Hi
# [Human 2] Hello, how are you doing today?
# [Human 1] I heard they are giving out some goodies in microkitchen.
# [Human 2] That's great. How's the food?
# [Human 1] I heard there are meals for lunch and dinner on sale for just under $1,000. I will chime in as soon as they get my order.
# [Human 2] That's good. I'll pick up something unhealthy and some good food. Do you have any good ramen?
# [Human 1] Ioners are a favorite, but I haven't tried ramen in a while. Not to brag but ramen is a pain in the arse and I'm not a moron - I know plenty of people who go to pet heaven.
# [Human 2] That's true. Though I admit, I'm a bit sad that I cannot get by trash can. Me personally, I don't like it when things bad happen to nice people.
# [Human 1] Are you a food person, a sight to see?
# [Human 2] Yes! I think of all the food I have eaten that had been turned into food before they are packaged and gone bad.
# [Human 1] Have you ever had bad ramen?
# [Human 2] I have never had bad ramen, but my bad experience with it is pretty bad. I have tried ramen hot dogs and pikachu. I will definitely try his.
# [Human 1] Great! Have you tried any of his other ramen options?
# [Human 2] He has never had pikachu, but pikachu is still bothering me. Got any good ramen snub?
# [Human 1] Hee hee hee! here it is :slightly_smiling_face: Phew! I love hot dogs or pikachu.
# [Human 2] Hot dogs and tennis? Yep, we had a lot of fun last week. We booked a room at a friends place and we snubbed pikachu. I think the pikachu that we snuck into the bar were too lazy to finish up before us.
# [Human 1] We SWEAT! Did we not say lazy? Did we not say anything about our meal?
# [Human 2] We SWEAT! Did we not say anything lazy? If we did, we probably would not be able to nap this much. We had a pretty good chance of getting snoozed.
# [Human 1] We slept well we>>>>>>>> thought but woke up too late
# [Human 2] We could have snoozed earlier had we known about the lagus ting
# [Human 1] We did not, and woke up too late
# [Human 2
#
# [301 | 10842.45] loss=0.04 avg=0.14
# [302 | 10879.30] loss=0.03 avg=0.14
# [303 | 10918.01] loss=0.03 avg=0.14
# [304 | 10954.47] loss=0.05 avg=0.14
# interrupted
# Saving ./data/models_trained/02_gp2simple_124M_20221120002951\model-304
# WARNING:tensorflow:From C:\Users\sjain\anaconda3\envs\HW2\lib\site-packages\tensorflow\python\training\saver.py:1064: remove_checkpoint (from tensorflow.python.checkpoint.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.

# %%
# retrieve saved previosuly custom fine-tuned model
checkpoint_dir="./data/models_trained/02_gp2simple_new124_124M_20221124005804"
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, checkpoint_dir=checkpoint_dir)
# Out:
# Loading checkpoint /content/drive/MyDrive/Colab Notebooks/CSCI 544: ANLP/NLP_Group_Project/GPT_3_Model/data/models_trained/02_gp2simple_new124_124M_20221124005804/run1/model-600

# %%
# Initialize Sentiment Analyzer
import nltk

nltk.download([
     "stopwords",
     "averaged_perceptron_tagger",
     "vader_lexicon",
     "punkt"
])

from nltk.sentiment import SentimentIntensityAnalyzer
sentimentAnalyzer = SentimentIntensityAnalyzer()
possibleSentiments = ['pos', 'neu', 'neg']
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# Initialize Generic / Discrete Model
from transformers import BlenderbotTokenizer, BlenderbotForConditionalGeneration

mname = "facebook/blenderbot-400M-distill"
discreteModel = BlenderbotForConditionalGeneration.from_pretrained(mname)
tokenizer = BlenderbotTokenizer.from_pretrained(mname)
# Out:
# Downloading:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/730M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/127k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/62.9k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/16.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]

# %%
# # Generate response
# question = input()
# # print()

# prefix = '[Human 2] '+ question + '\n[Human 1]'
# temperature = 0.90

# # check the sentiment of input prompt
# sentimentScores = sentimentAnalyzer.polarity_scores(question)

# # Printing sentiment scores
# print('\nSentiment Scores -')
# for sentiment in possibleSentiments:
#   print('{}: {}'.format(sentiment, sentimentScores[sentiment]))


# # Get the highest score/probability sentiment
# quesSentiment = None
# maxVal = -1
# for sentiment in possibleSentiments:
#   if sentimentScores[sentiment] > maxVal:
#     maxVal = sentimentScores[sentiment]
#     quesSentiment = sentiment


# # check if we call fine-tuned transformer for response, or the discrete/generic model
# if quesSentiment in ['pos', 'neu']:
#   # Use the fine-tuned model if sentiment is positive or neutral
#   print('\nCalling Fine-Tuned Transformer for response -')
#   text_generated = gpt2.generate(
#       sess,
#       checkpoint_dir=checkpoint_dir,
#       length=80,
#       temperature=temperature,
#       prefix=prefix,
#       return_as_list=True
#   )
#   # print(text_generated[0])

#   response = text_generated[0].split(sep='\n')
#   response = response[:2]

#   for i, row in enumerate(response):
#       # print(row)
#       person, sentence = row.split(sep=']', maxsplit=1)
#       person = person[1:]
#       sentence = sentence.strip()
#       if person == 'Human 2':
#           person = '\nQuestion: '
#       else:
#           person = 'Response: '
#       response[i] = person + sentence

#   for row in response:
#       print(row)

# # Use Generic/Discrete Model otherwise in case of hateful prompt
# else:
#   print('\n\nCalling Generic/Discrete Model for response -')

#   inputs = tokenizer([question], return_tensors="pt")
#   reply_ids = discreteModel.generate(**inputs)
#   response = tokenizer.batch_decode(reply_ids)
#   response = response[0]
#   response = response.split('>')[1].split('<')[0]
#   print('\nQuestion: ', question)
#   print('Response: ', response)
# Out:
# Do you have a cat?
#
# Sentiment Scores -
# pos: 0.0
# neu: 1.0
# neg: 0.0
#
# Calling Fine-Tuned Transformer for response -
#
# Question: Do you have a cat?
# Response: He's so cute I am imagining him playing soccer on his phone right now. I want to play it with him for a while, and then I'll get to play it with him actually. Are you planning anything for the holidays?

# %%
# Generate response
question = input()
# print()

prefix = '[Human 2] '+ question + '\n[Human 1]'
temperature = 0.90
res = ''

# check the sentiment of input prompt
sentimentScores = sentimentAnalyzer.polarity_scores(question)

# Printing sentiment scores
res += 'Sentiment Scores -'
for sentiment in possibleSentiments:
  res += '\n{}: {}'.format(sentiment, sentimentScores[sentiment])



# Get the highest score/probability sentiment
quesSentiment = None
maxVal = -1
for sentiment in possibleSentiments:
  if sentimentScores[sentiment] > maxVal:
    maxVal = sentimentScores[sentiment]
    quesSentiment = sentiment



# check if we call fine-tuned transformer for response, or the discrete/generic model
if quesSentiment in ['pos', 'neu']:
  # Use the fine-tuned model if sentiment is positive or neutral
  res += '\n\nCalling Fine-Tuned Transformer for response -'
  text_generated = gpt2.generate(
      sess,
      checkpoint_dir=checkpoint_dir,
      length=80,
      temperature=temperature,
      prefix=prefix,
      return_as_list=True
  )
  # print(text_generated[0])

  response = text_generated[0].split(sep='\n')
  response = response[:2]

  for i, row in enumerate(response):
      # print(row)
      person, sentence = row.split(sep=']', maxsplit=1)
      person = person[1:]
      sentence = sentence.strip()
      if person == 'Human 2':
          person = '\n\nQuestion: '
      else:
          person = '\nResponse: '
      response[i] = person + sentence

  for row in response:
      res += row

# Use Generic/Discrete Model otherwise in case of hateful prompt
else:
  res += '\n\nCalling Generic/Discrete Model for response -'

  inputs = tokenizer([question], return_tensors="pt")
  reply_ids = discreteModel.generate(**inputs)
  response = tokenizer.batch_decode(reply_ids)
  response = response[0]
  response = response.split('>')[1].split('<')[0]
  res += '\n\nQuestion: ' + question
  res += '\nResponse: ' + response
# Out:
# Want to travel to Europe?

# %%
print(res)
# Out:
# Sentiment Scores -
# pos: 0.245
# neu: 0.755
# neg: 0.0
#
# Calling Fine-Tuned Transformer for response -
#
# Question: Want to travel to Europe?
# Response: Yes! I want to one day go into space!
